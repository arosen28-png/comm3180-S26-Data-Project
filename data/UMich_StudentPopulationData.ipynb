# %%
ug_match = re.search(
    r"Undergraduate Enrollment\s+([\d,]+)\s+([\d,]+)\s+([\d,]+)",
    text
)
grad_match = re.search(
    r"Graduate Enrollment\s+([\d,]+)\s+([\d,]+)\s+([\d,]+)",
    text
)

if ug_match and grad_match:
    undergrad_ann_arbor = int(ug_match.group(1).replace(",", ""))
    graduate_ann_arbor = int(grad_match.group(1).replace(",", ""))
    total_ann_arbor = undergrad_ann_arbor + graduate_ann_arbor

    print("Ann Arbor undergrad:", undergrad_ann_arbor)
    print("Ann Arbor graduate:", graduate_ann_arbor)
    print("Ann Arbor total:", total_ann_arbor)
else:
    print("Could not find enrollment values.")
# Out:
# Could not find enrollment values.
