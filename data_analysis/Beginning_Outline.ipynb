# %% [markdown]
# We will be examining these schools: Berkeley (a UC school), UPenn (an urban ivy league), Michigan (a huge state school), and Wesleyan (a small, liberal arts school)

# %% [markdown]
# Specifically, we will be diving into Rent data, IPED (Integrated Postsecondary Education Data System), Population metrics, and Registered local businesses
